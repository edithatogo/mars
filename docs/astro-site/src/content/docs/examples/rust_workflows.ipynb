# %% [markdown]
# # Rust Runtime Notebook
#
# This notebook-equivalent captures the Rust runtime and ABI validation path.
#
# ## Workflow
#
# 1. Validate portable `ModelSpec` payloads through the ABI contract.
# 2. Replay predictions and design matrices with the runtime tests.
# 3. Keep the ABI versioned and host-language-facing tests green.
#
# ## Validation
#
# Run `cargo test --test foreign_tests`.
