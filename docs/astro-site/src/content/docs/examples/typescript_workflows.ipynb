# %% [markdown]
# # TypeScript Runtime Notebook
#
# This notebook-equivalent captures the TypeScript binding replay workflow.
#
# ## Workflow
#
# 1. Load a validated `ModelSpec` with `loadModelSpec(...)`.
# 2. Evaluate `designMatrix(...)` and `predict(...)`.
# 3. Use `fitModel()` only when the Rust CLI-backed training path is available.
#
# ## Validation
#
# Run `npm test`.
