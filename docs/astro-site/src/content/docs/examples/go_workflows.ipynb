# %% [markdown]
# # Go Runtime Notebook
#
# This notebook-equivalent captures the Go binding replay workflow.
#
# ## Workflow
#
# 1. Load a validated `ModelSpec` with `LoadModelSpec(...)`.
# 2. Evaluate `DesignMatrix(...)` and `Predict(...)`.
# 3. Use `FitModel(...)` when the Rust-backed training bridge is available.
#
# ## Validation
#
# Run `go test ./...`.
